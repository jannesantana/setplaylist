# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

url = "https://www.setlist.fm/setlist/the-plot-in-you/2025/poppodium-013-tilburg-netherlands-3358a08d.html"

options = Options()
options.add_argument("--headless")
driver = webdriver.Chrome(options=options)

driver.get(url)
time.sleep(3)  # wait for the JS to load

soup = BeautifulSoup(driver.page_source, "html.parser")
print(soup)
# Out:
# <html data-bs-theme="dark" xmlns="http://www.w3.org/1999/xhtml"><head><script async="" src="https://s0.2mdn.net/instream/video/client.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js?loadCastFramework=1" type="text/javascript"></script><link href="https://f.monetate.net" rel="dns-prefetch"/><link href="https://sb.monetate.net" rel="dns-prefetch"/><script async="" src="https://rules.quantcount.com/rules-p-98KjJHhiQX_yM.js"></script><script async="" charset="utf-8" src="https://se.monetate.net/js/3/a-a1627c0e/p/setlist.fm/t1717073559/0f804c04ac592d32/custom.js" type="text/javascript"></script><script async="" charset="utf-8" src="//imasdk.googleapis.com/js/sdkloader/ima3.js" type="text/javascript"></script><script async="" src="https://secure.quantserve.com/quant.js" type="text/javascript"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" charset="utf-8" src="https://ssl.p.jwpcdn.com/player/v/8.41.0/gapro.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://ssl.p.jwpcdn.com/player/v/8.41.0/jwpsrv.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://ssl.p.jwpcdn.com/player/v/8.41.0/googima.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" name="language"/>
# <meta content="The Plot in You,Poppodium 013, Tilburg, Netherlands,Europe 2025,2025,setlist,setlists" name="keywords"/>
# <meta content="Get the The Plot in You Setlist of the concert at Poppodium 013, Tilburg, Netherlands on November 3, 2025 from the Europe 2025 Tour and other The Plot in You Setlists for free on setlist.fm!" name="description"/>
# <meta content="light dark" name="color-scheme"/>
# <meta content="#85b146" name="theme-color"/>
# <link href="/img/icon-large.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/addons/SetlistSearch.xml" rel="search" title="Setlist.fm" type="application/opensearchdescription+xml"/>
# <link href="https://www.setlist.fm/setlist/the-plot-in-you/2025/poppodium-013-tilburg-netherlands-3358a08d.html" rel="canonical"/>
# <title>The Plot in You Concert Setlist at Poppodium 013, Tilburg on November 3, 2025 | setlist.fm</title>
# <!-- responsive -->
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://www.setlist.fm/linkback/pingback" rel="pingback"/><link as="font" crossorigin="anonymous" href="//w1.cdn.setlistfm.com/fonts/Roboto-Regular.ttf" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//w1.cdn.setlistfm.com/fonts/Roboto-Medium.ttf" rel="preload"/>
# <meta content="The Plot in You Setlist at Poppodium 013, Tilburg" property="og:title"/>
# <meta content="setlist.fm" property="og:site_name"/>
# <meta content="https://w1.cdn.setlistfm.com/img/sfm-logo.png" property="og:image"/>
# <meta content="setlist" property="og:type"/>
# <meta content="https://www.setlist.fm/setlist/the-plot-in-you/2025/poppodium-013-tilburg-netherlands-3358a08d.html" property="og:url"/>
# <meta content="38890339940" property="fb:app_id"/>
# <meta content="The Plot in You" property="qc:artist"/>
# <meta content="Poppodium 013, Tilburg, Netherlands" property="qc:venue"/>
# <link href="//w1.cdn.setlistfm.com/css/setlist-5.9.9-6-gf3ae43a-dirty.css" rel="stylesheet" type="text/css"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <script async="" id="www-widgetapi-script" src="https://www.youtube.com/s/player/4e51e895/www-widgetapi.vflset/www-widgetapi.js" type="text/javascript"></script><script async="" src="https://cmp.inmobi.com/tcfv2/53/cmp2.js?referer=www.setlist.fm" type="text/javascript"></script><script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript"></script><script async="" src="https://cmp.inmobi.com/choice/YNBzFQD2NK8uS/www.setlist.fm/choice.js?tag_version=V3" type="text/javascript"></script><script src="https://www.youtube.com/iframe_api"></script><script src="//w1.cdn.setlistfm.com/jquery/js/jquery.min-1.9.1.js" type="text/javascript"></script>
# <script src="//w1.cdn.setlistfm.com/jquery/js/jquery-migrate.min-1.1.1.js" type="text/javascript"></script>
# <script src="//w1.cdn.setlistfm.com/script/setlist-jquery-5.9.9-6-gf3ae43a-dirty.js" type="text/javascript"></script>
# <script src="//w1.cdn.setlistfm.com/script/wicket-1.4.23-molindo1.js" type="text/javascript"></script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# Wicket.Event.add(window, "load", function(event) { if (typeof gtag === 'function') {
# gtag('event', 'settimes_view', {
# 'page_type':'Setlist'
# });
# }
# ;});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('[data-toggle="tooltip"]').tooltip();});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#ida').click(function(event){event.stopPropagation();$('#idb').toggleClass('collapsed');});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#idc').click(function(event){event.stopPropagation();$('#idb').toggleClass('collapsed');});});
# /*-->]]>*/</script>
# <script src="//w1.cdn.setlistfm.com/script/setlist-5.9.9-6-gf3ae43a-dirty.js" type="text/javascript"></script>
# <script id="LiveNationAsyncAfterHeaderComponent" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#idd').click(function(event){event.stopPropagation(); loadReactComponent($('#idd'), $('#ide'), '/api/stat/setlist-user-attendances?r=1770309476', $('#idd--ajax-indicator'), false, null); });});
# /*-->]]>*/</script>
# <link href="//w1.cdn.setlistfm.com/react/js/react.production.min-16.14.0.js" rel="prefetch"/><link href="//w1.cdn.setlistfm.com/react/js/react-dom.production.min-16.14.0.js" rel="prefetch"/><link href="/api/stat/setlist-user-attendances?r=1770309476" rel="prefetch"/>
# <script id="at-molindo-setlist-ui-markup-youtube-YouTubePanel-0" type="text/javascript">
# var tag = document.createElement('script');
# tag.src = "https://www.youtube.com/iframe_api";
# var firstScriptTag = document.getElementsByTagName('script')[0];
# firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# </script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# YouTubeSearch.indicator='idf--ajax-indicator';
# YouTubeSearch.onLoad=function() {if (this.entries.length == 0) {alert('We are really, really, really sorry, but there is no video available here.')}}
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# Wicket.Event.add(window, "domready", function(event) { YouTubeSearch.setPlaylist([{"song":"Don't Look Away","artist":"The Plot in You"},{"song":"Divide","artist":"The Plot in You"},{"song":"Pretend","artist":"The Plot in You"},{"song":"Paradigm","artist":"The Plot in You"},{"song":"THE ONE YOU LOVED","artist":"The Plot in You"},{"song":"Face Me","artist":"The Plot in You"},{"song":"NOT JUST BREATHING","artist":"The Plot in You"},{"song":"Been Here Before","artist":"The Plot in You"},{"song":"Silence","artist":"The Plot in You"},{"song":"Forgotten","artist":"The Plot in You"},{"song":"Spare Me","artist":"The Plot in You"},{"song":"Closure","artist":"The Plot in You"},{"song":"Time Changes Everything","artist":"The Plot in You"},{"song":"Left Behind","artist":"The Plot in You"},{"song":"FEEL NOTHING","artist":"The Plot in You"}], false);;});
# /*-->]]>*/</script>
# <script src="//w1.cdn.setlistfm.com/script/jquery-plugins-5.9.9-6-gf3ae43a-dirty.js" type="text/javascript"></script>
# <script id="TimeagoBehavior" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
#
# jQuery.timeago.settings.cutoff = 7*24*60*60*1000;
# jQuery.timeago.settings.localeTitle = true;
# jQuery.timeago.settings.strings.seconds="seconds"
# jQuery.timeago.settings.allowFuture=true
# jQuery.timeago.settings.format = function(date) {
# function pad(val) {return val < 10 ? "0"+val : val};
# var months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'];
# return date.getDate() + " " + months[date.getMonth()] + " " + date.getFullYear() + ", "
# + pad(date.getHours()) + ":" + pad(date.getMinutes());
# };
# jQuery.timeago.settings.formatTitle = function(date) {
# function pad(val) {return val < 10 ? "0"+val : val};
# var days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'];
# var months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'];
# return days[date.getDay()] + ", " + date.getDate() + " " + months[date.getMonth()] + " " + date.getFullYear() + " at "
# + pad(date.getHours()) + ":" + pad(date.getMinutes())+ ":" + pad(date.getSeconds());
# };
# jQuery(document).ready(function() {
# jQuery("abbr.timeago").timeago();
# });
#
# /*-->]]>*/</script>
# <script src="//www.google.com/jsapi" type="text/javascript"></script>
# <script id="googleAjax-visualization" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# google.load('visualization','1',{"packages":["corechart"]});
# /*-->]]>*/</script><script charset="UTF-8" src="https://www.gstatic.com/charts/51/loader.js" type="text/javascript"></script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# google.setOnLoadCallback(function() {drawPieChart('id10',{"values":[{"label":"Dispose","value":3},{"label":"Vol. 1","value":3},{"label":"Vol. 3","value":3},{"label":"Swan Song","value":2},{"label":"Vol. 2","value":2},{"label":"Happiness in Self Destruction","value":1},{"label":"Others","value":1}],"numberLabel":"Songs","nameLabel":"Album"}, {"pieSliceText":"none","backgroundColor":"$(--bs-body-bg-bright)","pieHole":"0.8","legend":"none","is3D":"false","chartArea":{"top":"0","left":"0","width":"100%","height":"100%"},"colors":["#85B146","#C2CF44","#FEE94E","#FEC02E","#FD9726","#FC582F","#C44425"]},null, function(err) { document.getElementById(err.id).style.display = 'none';});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id11').click(function(event){event.stopPropagation();$('#id12').toggle(0, function() {$('#id11').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id13').click(function(event){event.stopPropagation();$('#id14').toggle(0, function() {$('#id13').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id15').click(function(event){event.stopPropagation();$('#id16').toggle(0, function() {$('#id15').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id17').click(function(event){event.stopPropagation();$('#id18').toggle(0, function() {$('#id17').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id19').click(function(event){event.stopPropagation();$('#id1a').toggle(0, function() {$('#id19').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id1b').click(function(event){event.stopPropagation();$('#id1c').toggle(0, function() {$('#id1b').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id1d').click(function(event){event.stopPropagation();$('#id1e').toggle(0, function() {$('#id1d').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id1f').click(function(event){event.stopPropagation();$('#id20').toggle(0, function() {$('#id1f').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){if (window.location.hash.startsWith('#sfm')) {loadReactComponent($('#id21'), $('#id22'), '/api/activity/activities?r=1770309476', $('#id21--ajax-indicator'), true, function(show) { $('#id1').toggle(!show); });}});
# /*-->]]>*/</script>
# <link href="/api/activity/activities?r=1770309476" rel="prefetch"/><script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id1').click(function(event){event.stopPropagation(); loadReactComponent($('#id1'), $('#id22'), '/api/activity/activities?r=1770309476', $('#id1--ajax-indicator'), true, function(show) { $('#id1').toggle(!show); }); });});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id23').click(function(event){event.stopPropagation();$('#id24').toggleClass('collapsed');});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id25').click(function(event){event.stopPropagation();$('#id24').toggleClass('collapsed');});});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){$('#id26').click(function(event){event.stopPropagation();$('#id27').toggle(0, function() {$('#id26').toggleClass('active');});});});
# /*-->]]>*/</script>
# <script id="JQueryStickyComponentBehavior-id28" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(window).load(function(){
#
# 	var query = responsive.mdg;
# var options = {offset_top:15,bottoming:true,parent:$('.container'),spacer:false,off_callbacks:[$.VideoPlayerOutOfViewport.on]};
# var offOptions = function() {
# if (options.off_callbacks && options.off_callbacks.length > 0) {
# for (var i = 0; i < options.off_callbacks.length; i++) {
# options.off_callbacks[i]();
# }
# }
# }
# var updateSticky = function() {
#
#  if ($('#id28').height() < $(window).height()) {
# $('#id28').stick_in_parent(options);
#
#  if (options.recalc_events && options.recalc_events.length > 0) {
# for (var i = 0; i < options.recalc_events.length; i++) {
# $(document.body).on(options.recalc_events[i], function() {
# $('#id28').trigger("sticky_kit:recalc");
# });
# }
# }
# if (options.bottoming) {
# $('#id28').on('sticky_kit:bottom', function(e) {
# $(this).parent().css('position', 'static');
# })
# .on('sticky_kit:unbottom', function(e) {
# $(this).parent().css('position', 'relative');
# });
# }
# } else {
# $('#id28').trigger("sticky_kit:detach");
#
#  if (options.recalc_events && options.recalc_events.length > 0) {
# for (var i = 0; i < options.recalc_events.length; i++) {
# $(document.body).off(options.recalc_events[i]);
# }
# }
# offOptions();
# }
# };
# query.addListener(updateSticky);
# if (query.matches){
# updateSticky();
# } else {
# offOptions();
# }
# responsive.stickyAd = query;
# });
#
# /*-->]]>*/</script>
# <script src="//content.jwplatform.com/libraries/CAKoASwY.js" type="text/javascript"></script>
# <script id="ln-jwplayer-control-js-wawa" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#
# /*-->]]>*/</script>
# <script id="ln-jwplayer-control-js" src="//setlist-utils.lncontent.works/player.js" type="text/javascript"></script>
# <link href="//setlist-utils.lncontent.works/player.css" rel="stylesheet" type="text/css"/>
# <script id="LiveNationAsyncDynamicAdslotPanel-Gallery" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
#
# function newGalleryDynamicAdslot(markupId, callback) {
# googletag.cmd.push(function() {
# var slot = googletag.defineSlot('/6025/setlist/setlist/gallery', [300, 250],markupId)
# .addService(googletag.pubads())
# .setTargeting("page", "gallery")
# .setTargeting("pagepos", "502");
# if (callback) {
# googletag.pubads().addEventListener('slotRenderEnded', function(event) {
# if (event.slot.getSlotElementId() == markupId) {
# var myEvent = {
# isEmpty : event.isEmpty
# };
# callback(myEvent);
# }
# });
# }
# googletag.display(markupId)
# });
# }
# /*-->]]>*/</script>
# <script id="at.molindo.setlist.ui.panels.border.Header/Header.template.js" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# (function() {
# const pref = typeof (window.localStorage) === "object" ? window.localStorage.getItem("sfm-theme") : null;
# const dark = pref === null ? window.matchMedia('(prefers-color-scheme: dark)').matches : pref === 'dark';
# document.documentElement.setAttribute("data-bs-theme", dark ? 'dark' : 'light');
# })();
# /*-->]]>*/</script>
# <script id="at.molindo.setlist.ui.panels.border.Header/Header-instrumentation.js" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
#
# function initHeaderInstrumentation() {
# if (typeof window.theme === 'undefined') {
# console.warn('theme not defined');
# } else {
# window.theme.addEventListener(function(event) {
# const previousTheme = event.detail.theme == 'dark' ? 'light' : 'dark';
# if (typeof gtag === 'function') {
# gtag('event', 'theme_change', {
# 'theme' : previousTheme,
# 'bannerVisible': false
# });
# }
# });
# }
# }
#
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# Wicket.Event.add(window, "load", function(event) { initHeaderInstrumentation();;});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# Wicket.Event.add(window, "domready", function(event) { initClearQueryLink($('#id29'), $('#id2a'));;});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# $(document).ready(function(){initAutocomplete($('#id29'), $('#id2b'));});
# /*-->]]>*/</script>
# <script type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# Wicket.Event.add(window, "load", function(event) { initThemeLinkStates();;});
# /*-->]]>*/</script>
# <script id="QuantcastChoiceJavascriptComponent" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# (function() {
# var host = window.location.hostname;
# var element = document.createElement('script');
# var firstScript = document.getElementsByTagName('script')[0];
# var url = 'https://cmp.inmobi.com'
# .concat('/choice/', 'YNBzFQD2NK8uS', '/', host, '/choice.js?tag_version=V3');
# var uspTries = 0;
# var uspTriesLimit = 3;
# element.async = true;
# element.type = 'text/javascript';
# element.src = url;
# firstScript.parentNode.insertBefore(element, firstScript);
# function makeStub() {
# var TCF_LOCATOR_NAME = '__tcfapiLocator';
# var queue = [];
# var win = window;
# var cmpFrame;
# function addFrame() {
# var doc = win.document;
# var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
# if (!otherCMP) {
# if (doc.body) {
# var iframe = doc.createElement('iframe');
# iframe.style.cssText = 'display:none';
# iframe.name = TCF_LOCATOR_NAME;
# doc.body.appendChild(iframe);
# } else {
# setTimeout(addFrame, 5);
# }
# }
# return !otherCMP;
# }
# function tcfAPIHandler() {
# var gdprApplies;
# var args = arguments;
# if (!args.length) {
# return queue;
# } else if (args[0] === 'setGdprApplies') {
# if (
# args.length > 3 &&
# args[2] === 2 &&
# typeof args[3] === 'boolean'
# ) {
# gdprApplies = args[3];
# if (typeof args[2] === 'function') {
# args[2]('set', true);
# }
# }
# } else if (args[0] === 'ping') {
# var retr = {
# gdprApplies: gdprApplies,
# cmpLoaded: false,
# cmpStatus: 'stub'
# };
# if (typeof args[2] === 'function') {
# args[2](retr);
# }
# } else {
# if(args[0] === 'init' && typeof args[3] === 'object') {
# args[3] = Object.assign(args[3], { tag_version: 'V3' });
# }
# queue.push(args);
# }
# }
# function postMessageEventHandler(event) {
# var msgIsString = typeof event.data === 'string';
# var json = {};
# try {
# if (msgIsString) {
# json = JSON.parse(event.data);
# } else {
# json = event.data;
# }
# } catch (ignore) {}
# var payload = json.__tcfapiCall;
# if (payload) {
# window.__tcfapi(
# payload.command,
# payload.version,
# function(retValue, success) {
# var returnMsg = {
# __tcfapiReturn: {
# returnValue: retValue,
# success: success,
# callId: payload.callId
# }
# };
# if (msgIsString) {
# returnMsg = JSON.stringify(returnMsg);
# }
# if (event && event.source && event.source.postMessage) {
# event.source.postMessage(returnMsg, '*');
# }
# },
# payload.parameter
# );
# }
# }
# while (win) {
# try {
# if (win.frames[TCF_LOCATOR_NAME]) {
# cmpFrame = win;
# break;
# }
# } catch (ignore) {}
# if (win === window.top) {
# break;
# }
# win = win.parent;
# }
# if (!cmpFrame) {
# addFrame();
# win.__tcfapi = tcfAPIHandler;
# win.addEventListener('message', postMessageEventHandler, false);
# }
# };
# makeStub();
# function makeGppStub() {
# const CMP_ID = 10;
# const SUPPORTED_APIS = [
# '2:tcfeuv2',
# '6:uspv1',
# '7:usnatv1',
# '8:usca',
# '9:usvav1',
# '10:uscov1',
# '11:usutv1',
# '12:usctv1'
# ];
# window.__gpp_addFrame = function (n) {
# if (!window.frames[n]) {
# if (document.body) {
# var i = document.createElement("iframe");
# i.style.cssText = "display:none";
# i.name = n;
# document.body.appendChild(i);
# } else {
# window.setTimeout(window.__gpp_addFrame, 10, n);
# }
# }
# };
# window.__gpp_stub = function () {
# var b = arguments;
# __gpp.queue = __gpp.queue || [];
# __gpp.events = __gpp.events || [];
# if (!b.length || (b.length == 1 && b[0] == "queue")) {
# return __gpp.queue;
# }
# if (b.length == 1 && b[0] == "events") {
# return __gpp.events;
# }
# var cmd = b[0];
# var clb = b.length > 1 ? b[1] : null;
# var par = b.length > 2 ? b[2] : null;
# if (cmd === "ping") {
# clb(
# {
# gppVersion: "1.1",
#  cmpStatus: "stub",
#  cmpDisplayStatus: "hidden",
#  signalStatus: "not ready",
#  supportedAPIs: SUPPORTED_APIS,
#  cmpId: CMP_ID,
#  sectionList: [],
# applicableSections: [-1],
# gppString: "",
# parsedSections: {},
# },
# true
# );
# } else if (cmd === "addEventListener") {
# if (!("lastId" in __gpp)) {
# __gpp.lastId = 0;
# }
# __gpp.lastId++;
# var lnr = __gpp.lastId;
# __gpp.events.push({
# id: lnr,
# callback: clb,
# parameter: par,
# });
# clb(
# {
# eventName: "listenerRegistered",
# listenerId: lnr,
#  data: true,
#  pingData: {
# gppVersion: "1.1",
#  cmpStatus: "stub",
#  cmpDisplayStatus: "hidden",
#  signalStatus: "not ready",
#  supportedAPIs: SUPPORTED_APIS,
#  cmpId: CMP_ID,
#  sectionList: [],
# applicableSections: [-1],
# gppString: "",
# parsedSections: {},
# },
# },
# true
# );
# } else if (cmd === "removeEventListener") {
# var success = false;
# for (var i = 0; i < __gpp.events.length; i++) {
# if (__gpp.events[i].id == par) {
# __gpp.events.splice(i, 1);
# success = true;
# break;
# }
# }
# clb(
# {
# eventName: "listenerRemoved",
# listenerId: par,
#  data: success,
#  pingData: {
# gppVersion: "1.1",
#  cmpStatus: "stub",
#  cmpDisplayStatus: "hidden",
#  signalStatus: "not ready",
#  supportedAPIs: SUPPORTED_APIS,
#  cmpId: CMP_ID,
#  sectionList: [],
# applicableSections: [-1],
# gppString: "",
# parsedSections: {},
# },
# },
# true
# );
# } else if (cmd === "hasSection") {
# clb(false, true);
# } else if (cmd === "getSection" || cmd === "getField") {
# clb(null, true);
# }
#
#  else {
# __gpp.queue.push([].slice.apply(b));
# }
# };
# window.__gpp_msghandler = function (event) {
# var msgIsString = typeof event.data === "string";
# try {
# var json = msgIsString ? JSON.parse(event.data) : event.data;
# } catch (e) {
# var json = null;
# }
# if (typeof json === "object" && json !== null && "__gppCall" in json) {
# var i = json.__gppCall;
# window.__gpp(
# i.command,
# function (retValue, success) {
# var returnMsg = {
# __gppReturn: {
# returnValue: retValue,
# success: success,
# callId: i.callId,
# },
# };
# event.source.postMessage(msgIsString ? JSON.stringify(returnMsg) : returnMsg, "*");
# },
# "parameter" in i ? i.parameter : null,
# "version" in i ? i.version : "1.1"
# );
# }
# };
# if (!("__gpp" in window) || typeof window.__gpp !== "function") {
# window.__gpp = window.__gpp_stub;
# window.addEventListener("message", window.__gpp_msghandler, false);
# window.__gpp_addFrame("__gppLocator");
# }
# };
# makeGppStub();
# var uspStubFunction = function() {
# var arg = arguments;
# if (typeof window.__uspapi !== uspStubFunction) {
# setTimeout(function() {
# if (typeof window.__uspapi !== 'undefined') {
# window.__uspapi.apply(window.__uspapi, arg);
# }
# }, 500);
# }
# };
# var checkIfUspIsReady = function() {
# uspTries++;
# if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
# console.warn('USP is not accessible');
# } else {
# clearInterval(uspInterval);
# }
# };
# if (typeof window.__uspapi === 'undefined') {
# window.__uspapi = uspStubFunction;
# var uspInterval = setInterval(checkIfUspIsReady, 6000);
# }
# })();
# /*-->]]>*/</script>
# <script id="at.molindo.setlist.ui.panels.border.Footer" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || Object.keys(consents).length !== 0) {
# var theLi = $('<li>');
# var myLink = $('<a>',{
#   text: 'Privacy Settings',
#   title: 'Edit your consent preferences',
#   onclick: 'window.__tcfapi("displayConsentUi",2, function() {}); return false;',
#   href: '#'
# }).appendTo(theLi);
# $(theLi).appendTo($('#id2c'));
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# }
# });
# /*-->]]>*/</script>
# <script id="page-attrs" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# var sfmPageAttributes = {"artist":{"mbid":"c2e7d4ac-5e30-4b55-99b7-e49d99fd7c63","name":"The Plot in You"},"venue":{"city":"Tilburg","name":"Poppodium 013","country":"NL"}}
# /*-->]]>*/</script>
# <script id="ln-async-loadlib" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
#
# /*-->]]>*/</script>
# <script id="ln-async-init" type="text/javascript"><!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || Object.keys(consents).length !== 0) {
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# googletag.cmd.push(function() {
# googletag.pubads().enableSingleRequest();
# googletag.pubads().enableAsyncRendering();
# googletag.pubads().collapseEmptyDivs(true);
# googletag.pubads().setTargeting("page","setlist");
# googletag.pubads().setTargeting("mbid", "c2e7d4ac-5e30-4b55-99b7-e49d99fd7c63");
# googletag.pubads().setTargeting("genre", "Rock");
# googletag.pubads().setTargeting("subgenre", "Alternative Rock");
# if (responsive.sml.matches) {
# googletag.defineOutOfPageSlot('/6025/setlist/setlist/settimes','id2')
# .addService(googletag.pubads())
# .setTargeting("pagepos", "556");
# }
# googletag.defineSlot('/6025/setlist/setlist/listings', 'fluid','id3')
# .addService(googletag.pubads())
# .setTargeting("listings_position", "15")
# .setTargeting("pagepos", "505");
# if (responsive.mdg.matches) {
# googletag.defineOutOfPageSlot('/6025/setlist/setlist/settimes','id4')
# .addService(googletag.pubads())
# .setTargeting("pagepos", "556");
# }
# googletag.defineSlot('/6025/setlist/setlist/sidebar', [[300, 250], [300, 600]],'id5')
# .defineSizeMapping(googletag.sizeMapping().
# addSize([1024, 50],[[300, 250], [300, 600]]).addSize([0, 0],[]).build())
# .addService(googletag.pubads())
# .setTargeting("pagepos", "502");
# googletag.defineOutOfPageSlot('/6025/setlist/setlist/syndication','id6')
# .addService(googletag.pubads())
# .setTargeting("pagepos", "555");
# googletag.defineSlot('/6025/setlist/setlist/leaderboard', [[970, 250], [970, 90], [970, 66], [728, 90], [300, 50], [320, 50]],'id7')
# .defineSizeMapping(googletag.sizeMapping().
# addSize([1024, 50],[[970, 250], [970, 90], [970, 66], [728, 90], 'fluid']).addSize([800, 50],[[728, 90], 'fluid']).addSize([0, 0],[]).build())
# .addService(googletag.pubads())
# .setTargeting("pagepos", "501");
# googletag.defineSlot('/6025/setlist/setlist/leaderboard', [[970, 250], [970, 90], [970, 66], [728, 90], [300, 50], [320, 50]],'id8')
# .defineSizeMapping(googletag.sizeMapping().
# addSize([1024, 50],[]).addSize([800, 50],[]).addSize([0, 0],[[300, 50], [320, 50], 'fluid']).build())
# .addService(googletag.pubads())
# .setTargeting("pagepos", "691");
# googletag.defineSlot('/6025/setlist/setlist/adhesion', [320, 50],'id9')
# .defineSizeMapping(googletag.sizeMapping().
# addSize([1024, 50],[]).addSize([800, 50],[]).addSize([0, 0],[[320, 50]]).build())
# .addService(googletag.pubads())
# .setTargeting("pagepos", "690");
# googletag.pubads().addEventListener('slotRenderEnded', function(event) {
# if(event.slot.getSlotElementId() == 'id3' && event.isEmpty) { $('#id3').parent().hide(); }
# if(event.slot.getSlotElementId() == 'id9' && !event.isEmpty) {
# var icon = $('<span class=\"fa-stack\"><i class=\"fa fa-circle fa-stack-2x\"><\/i><i class=\"fa fa-times fa-stack-1x fa-inverse\"><\/i><\/span>');
# var sr = $('<span>', {
# class: 'sr-only',
# text: 'Close Advertisement',
# });
# var link = $('<a>',{
# title: 'Close Advertisement',
# class: 'closeLink',
# href: '#',
# click: function(){
# $('#id9').remove();
# if ('adhesionAdVisible' != '') {
# $('body').removeClass('adhesionAdVisible');
# }
# return false;
# }
# });
# icon.appendTo(link);
# sr.appendTo(link);
# link.appendTo($('#id9'));
# if ('adhesionAdVisible' != '') {
# $('body').addClass('adhesionAdVisible');
# }
# }});
# googletag.pubads().addEventListener('slotOnload', function(event) {
#
# if(event.slot.getSlotElementId() == 'id7' && !event.isEmpty && responsive.smg.matches) {
# var cont = $('#id7');
# var h = cont.height();
# var toggleClass = function() {
# if (cont.visible(true)) {
# cont.removeClass('timedSticky');
# cont.css("height", "auto");
# } else {
# if (!cont.hasClass("timedSticky")) {
# cont.addClass('timedSticky');
# cont.css("height", h + "px");
# }
# }
# }
# $(window).on('scroll', toggleClass);
# setTimeout(function() {
# $(window).off('scroll', toggleClass);
# var child = $('#id7 > div');
# if (cont.hasClass("timedSticky")) {
# child.css("transition-timing-function", "ease-out");
# child.css("transition", "0.5s");
# child.css("transform", "translateY(-" + child.outerHeight() + "px)");
# setTimeout(function() {
# cont.removeClass('timedSticky');
# child.css("transform", "none");
#
#  }, 550);
# }
# }, 3000);
# }});
# googletag.enableServices();
# });
# }
# });
# /*-->]]>*/</script>
# <script defer="defer" src="https://9f3a81a29eb8.edge.sdk.awswaf.com/9f3a81a29eb8/8b43781430ec/challenge.js" type="text/javascript"></script>
# <link href="https://www.gstatic.com/charts/51/css/core/tooltip.css" id="load-css-0" rel="stylesheet" type="text/css"/><link href="https://www.gstatic.com/charts/51/css/util/util.css" id="load-css-1" rel="stylesheet" type="text/css"/><script charset="UTF-8" src="https://www.gstatic.com/charts/51/js/jsapi_compiled_default_module.js" type="text/javascript"></script><script charset="UTF-8" src="https://www.gstatic.com/charts/51/js/jsapi_compiled_graphics_module.js" type="text/javascript"></script><script charset="UTF-8" src="https://www.gstatic.com/charts/51/js/jsapi_compiled_ui_module.js" type="text/javascript"></script><script charset="UTF-8" src="https://www.gstatic.com/charts/51/js/jsapi_compiled_corechart_module.js" type="text/javascript"></script><style type="text/css"> .qc-cmp-button {    background-color: #85b146 !important;    border-color: #85b146 !important;  }  .qc-cmp-button:hover {    border-color: #85b146 !important;  }  .qc-cmp-alt-action,  .qc-cmp-link {    color: #85b146 !important;  }  .qc-cmp-button.qc-cmp-secondary-button:hover {    background-color: #85b146 !important;    border-color: #85b146 !important;  }  .qc-cmp-button.qc-cmp-secondary-button:hover {    color: #ffffff !important;  }  .qc-cmp-button.qc-cmp-secondary-button {    color: #85b146 !important;  }  .qc-cmp-button.qc-cmp-secondary-button {    background-color: #eee !important;    border-color: transparent !important;  }  .qc-cmp-ui a,  .qc-cmp-ui .qc-cmp-alt-action {    color: #85b146 !important;  } </style><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script async="" src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202602040101/pubads_impl.js"></script><link href="https://securepubads.g.doubleclick.net/pagead/managed/dict/m202602100101/gpt" rel="compression-dictionary"/><script id="__tcfapiuiscript" src="https://cmp.inmobi.com/tcfv2/53/cmp2ui-en.js" type="text/javascript"></script><style data-s="" qc-data-emotion="css-global"></style><style data-s="" qc-data-emotion="css"></style><style media="screen">.jw-plugin-googima{overflow:hidden;width:100%;height:100%;display:block;visibility:hidden;pointer-events:none;opacity:0}.jw-plugin-googima.jw-ad-instream{visibility:visible;display:block;pointer-events:all;opacity:1}.jw-plugin-googima.jw-ad-instream .jw-ads-view>:not(div),.jw-plugin-googima.jw-ad-instream .jw-ads-view>div:not(:empty){width:100%;height:100%}.jw-plugin-googima.jw-ad-linear{top:0;left:0;bottom:0}.jw- ...
# <body><div class="qc-cmp2-container" data-nosnippet="" id="qc-cmp2-container"><div class="qc-cmp2-main" data-nosnippet="" id="qc-cmp2-main"><div class="qc-cmp-cleanslate css-184wqfx" height="413"><div aria-label="qc-cmp2-ui" aria-modal="true" class="css-1fq12rn" id="qc-cmp2-ui" role="dialog" tabindex="0"><div class="qc-cmp2-summary-section"><div class="qc-cmp2-consent-info"><div class="qc-cmp2-publisher-logo-container"><figure><div class="logo-container css-1s94o35" height="67" width="300"><img alt="Publisher Logo" src="https://setlist-utils.lncontent.works/images/logo-setlistfm2.svg?qc-size=300,67"/></div><h2>We value your privacy</h2></figure><div class="qc-cmp2-summary-info qc-cmp2-logo-displayed"><div class=""> We and our <button class="qc-cmp2-link-inline css-1u9v4fx" mode="link" size="large">partners</button> store and/or access information on a device, such as cookies and process personal data, such as unique identifiers and standard information sent by a device for personalised advertising and content, advertising and content measurement, audience research and services development.  With your permission we and our partners may use precise geolocation data and identification through device scanning. You may click to consent to our and our 1565 partners’ processing as described above. Alternatively you may access more detailed information and change your preferences before consenting or to refuse consenting.  Please note that some processing of your personal data may not require your consent, but you have a right to object to such processing. Your preferences will apply to this website only. You can change your preferences or withdraw your consent at any time by returning to this site and clicking the "Privacy" button at the bottom of the webpage. </div></div></div></div></div><div class="qc-cmp2-footer qc-cmp2-footer-overlay"><div class="qc-cmp2-summary-buttons"><button class="css-1qmzi2h" mode="secondary" size="large"><span>MORE OPTIONS</span></button><button class="css-zfj8x7" mode="primary" size="large"><span>AGREE</span></button></div></div></div></div></div></div>
# <script async="true" src="https://www.googletagmanager.com/gtag/js?id=G-255PHLG789" type="text/javascript"></script>
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'G-255PHLG789', {
# 'content_group':'setlist_view',
# 'theme':(typeof window.theme === "object" ? window.theme.getCurrentlyActive() : 'undefined')
# });
# /*-->]]>*/
# </script>
# <!-- Begin Monetate ExpressTag Sync v8.1. Place at start of document head. DO NOT ALTER. -->
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || consents['2']) {
# var monetateT = new Date().getTime();} else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# }
# });
# /*-->]]>*/
# </script>
# <script src="//se.monetate.net/js/2/a-a1627c0e/p/setlist.fm/entry.js"></script><script id="id2d" type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || consents['2']) {
# var resource = document.createElement('script');
# resource.src = "//se.monetate.net/js/2/a-a1627c0e/p/setlist.fm/entry.js";
# var script = document.getElementById('id2d');
# script.parentNode.insertBefore(resource, script);
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# }
# });
# /*-->]]>*/
# </script>
# <!-- End Monetate tag. -->
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || consents['2']) {
# window.monetateQ = window.monetateQ || [];
# window.monetateQ.push(["setPageType", "setlist"]);
# window.monetateQ.push(["trackData"]);
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# }
# });
# /*-->]]>*/
# </script>
# <!-- content -->
# <div id="id2e" style="display:none"></div>
# <div class="body">
# <div class="header">
# <div class="container">
# <div class="row visiblePrint">
# <div class="col-xs-6 logo-col hidden-print col-md-3">
# <div class="logo-navi">
# <a class="logo" href="../../../" title="Back to the home page"><span class="sr-only">setlist.fm</span></a>
# </div>
# </div>
# <div class="col-xs-6 col-md-3 link-col hidden-print visible-xs visible-sm themeContainer add-setlist-top">
# <span>
# <a class="theme" href="javascript:theme.toggle()">
# <span>Change theme</span>
# </a>
# <a class="btn nestedInverse" href="../../../edit" rel="nofollow" title="So you've been to a concert? Add the setlist!">
# <i class="fa fa-plus"></i> <span><span class="hidden-xs">Add </span>Setlist</span>
# </a>
# </span>
# </div>
# <div class="col-xs-12 col-md-6 search-col hidden-print">
# <div class="search">
# <!-- search box -->
# <form action="../../../search" autocomplete="off" class="searchForm" id="id2b" method="get" name="searchBox">
# <div aria-expanded="false" aria-haspopup="listbox" aria-owns="gen-id-100000" class="inputCont" id="id2f" role="combobox">
# <input aria-autocomplete="list" aria-controls="gen-id-100000" id="id29" name="query" placeholder="Search for Artist, Venue, Tour, ..." type="search" value=""/><div aria-live="polite" class="sr-only" role="status"></div>
# <button class="visible-lg visible-md searchButton" style="display: inline-block;"><span class="sr-only">Search</span></button>
# <a class="hideSearch hidden-lg hidden-md" href="javascript:void(0);" id="id2a" rel="nofollow" style="display: none !important;">
# <span class="close">
# <span class="sr-only">Clear search text</span>
# </span>
# </a>
# </div>
# <ul aria-label="Search results" class="typeahead dropdown-menu" id="gen-id-100000" role="listbox" style="position: fixed; top: 111px; left: 16px; display: none; width: 709px;"></ul></form>
# </div>
# </div>
# <div class="col-xs-12 col-md-3 link-col hidden-xs hidden-sm text-right hidden-print themeContainer">
# <span>
# <a class="theme" href="javascript:theme.toggle()">
# <span>Change theme</span>
# </a>
# </span>
# </div>
# <div class="printHeader visible-print col-xs-12">
# <img alt="setlist.fm logo" height="43" src="//w1.cdn.setlistfm.com/img/sfm-logo.png" width="194"/>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden-print subHeader" id="id30">
# <div class="container">
# <div class="row">
# <div class="col-sm-12 col-md-8 main-navi">
# <ul class="list-inline">
# <li>
# <a href="../../../setlists" title="View the most popular and most attended setlists.">
# <span>Setlists</span>
# </a>
# </li><li>
# <a href="../../../artists" title="View the most popular and most attended artists.">
# <span>Artists</span>
# </a>
# </li><li>
# <a href="../../../festivals" title="View the most popular and most attended festivals.">
# <span>Festivals</span>
# </a>
# </li><li>
# <a href="../../../venues" title="View the most popular and most attended venues.">
# <span>Venues</span>
# </a>
# </li><li>
# <a href="../../../statistics" title="View interesting setlist statistics.">
# <span class="visible-lg-inline visible-xs-inline">Statistics</span>
# <span class="visible-md-inline visible-sm-inline">Stats</span>
# </a>
# </li><li>
# <a href="../../../news" title="Get the latest concert news.">
# <span>News</span>
# </a>
# </li><li>
# <a href="../../../forum" title="Talk about concerts, music and setlist.fm in the forum">
# <span>Forum</span>
# </a>
# </li>
# </ul>
# <div class="menu-buttons visible-xs visible-sm text-right">
# <a class="showMenu" rel="nofollow"><span class="sr-only">Show Menu</span></a>
# <a class="hideMenu" rel="nofollow"><span class="sr-only">Hide Menu</span></a>
# </div>
# </div>
# <div class="hidden-xs col-sm-12 col-md-4 user-navi">
# <div class="text-right user-fragment">
# <a class="btn nestedInverse hidden-xs hidden-sm add-setlist-navi" href="../../../edit" rel="nofollow" title="So you've been to a concert? Add the setlist!"><i class="fa fa-plus"></i> <span><span class="visible-lg-inline">Add </span>Setlist</span></a>
# <div class="login-group btn-group">
# <a class="btn loginBtn nestedInverse" href="../../../signin?redirecturl=/setlist/the-plot-in-you/2025/poppodium-013-tilburg-netherlands-3358a08d.html" title="Sign in to your account"><i class="fa fa-lock"></i> <span>Sign in</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <ol class="breadCrumbBar col-xs-12" typeof="BreadcrumbList" vocab="http://schema.org/">
# <li>You are here: </li><li property="itemListElement" typeof="ListItem">
# <a href="../../../" property="item" typeof="WebPage"><span property="name">setlist.fm</span></a><meta content="1" property="position"/>
# </li><li class="breadCrumbDelimiter">&gt;</li><li property="itemListElement" typeof="ListItem">
# <a href="../../../artists" property="item" typeof="WebPage"><span property="name">Artists</span></a><meta content="2" property="position"/>
# </li><li class="breadCrumbDelimiter">&gt;</li><li property="itemListElement" typeof="ListItem">
# <a href="../../../artist/browse/p/1.html" property="item" title="P" typeof="WebPage"><span property="name">P</span></a><meta content="3" property="position"/>
# </li><li class="breadCrumbDelimiter">&gt;</li><li property="itemListElement" typeof="ListItem">
# <a href="../../../setlists/the-plot-in-you-3d18dc3.html" property="item" title="Plot in You, The" typeof="WebPage"><span property="name">Plot in You, The</span></a><meta content="4" property="position"/>
# </li><li class="breadCrumbDelimiter">&gt;</li><li property="itemListElement" typeof="ListItem">
# <span title="View this The Plot in You setlist"><em class="link"><span property="name">November 3, 2025 Setlist</span></em></span><meta content="5" property="position"/>
# </li>
# </ol>
# </div>
# <div class="row">
# <div class="prmtnTop">
# <div class="leaderBoard" id="id7" style="display: none;">
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || Object.keys(consents).length !== 0) {
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# googletag.cmd.push(function() { googletag.display('id7'); });}
# });
# /*-->]]>*/
# </script>
# </div>
# </div><div class="prmtnMbanner">
# <div class="leaderBoard" data-google-query-id="CPOu2IOxz5IDFSTWewodWIk5yg" id="id8" style="display: none;">
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || Object.keys(consents).length !== 0) {
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# googletag.cmd.push(function() { googletag.display('id8'); });}
# });
# /*-->]]>*/
# </script>
# <div id="google_ads_iframe_/6025/setlist/setlist/leaderboard_1__container__" style="border: 0pt none; width: 300px; height: 0px;"></div></div>
# </div>
# </div>
# <div class="row main">
# <div class="mainColumn col-xs-12 col-md-8">
# <div class="row visiblePrint">
# <div class="col-xs-12 transparentBox setlistInfo" id="id31">
# <div class="dateBlockContainer">
# <div class="dateBlock">
# <span class="month">Nov</span>
# <span class="day">3</span>
# <span class="year">2025</span>
# </div>
# </div>
# <div class="infoContainer">
# <div class="font-meeker font-size-normal hidden-xs editSetlistLink btn-group text-left hidden-print">
# <a aria-expanded="false" aria-haspopup="true" class="btn btn-link btnEdit nested" data-toggle="dropdown" type="button">
# <i class="fa fa-pencil fa-fw"></i> <span>Edit setlist</span>
# <span class="btnToggle"><i class="fa fa-chevron-down fa-adapt-height"></i></span>
# <span class="sr-only">Show all edit options</span>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a class="editLink" href="../../../edit?setlist=3358a08d&amp;step=song" rel="nofollow nofollow" title="Edit setlist">
# <span>Edit setlist songs</span>
# </a>
# </li>
# <li>
# <a class="editLink" href="../../../edit?setlist=3358a08d&amp;step=artist" rel="nofollow nofollow" title="Edit setlist">
# <span>Edit venue &amp; date</span>
# </a>
# </li>
# <li>
# <a class="editLink" href="../../../edit?setlist=3358a08d&amp;step=times" rel="nofollow nofollow" title="Edit setlist">
# <span>Edit set times</span>
# </a>
# </li>
# <li>
# <a class="editLink" href="../../../edit?setlist=3358a08d&amp;step=tour" rel="nofollow nofollow" title="Edit setlist">
# <span>Edit tour</span>
# </a>
# </li>
# <li>
# <a class="editLink" href="../../../assign-festival?setlist=3358a08d" rel="nofollow" title="Add setlist to festival">
# <span>Add to festival</span>
# </a>
# </li>
# <li>
# <a class="editLink" href="../../../report/setlist?setlist=3358a08d" rel="nofollow nofollow" title="Report this setlist">Report setlist</a>
# </li>
# </ul>
# </div>
# <div class="setlistHeadline">
# <h1>
# <strong><a href="../../../setlists/the-plot-in-you-3d18dc3.html" title="View The Plot in You setlists">The Plot in You</a> Setlist</strong>
# <span>at <a href="../../../venue/poppodium-013-tilburg-netherlands-3bd790b8.html" title="More setlists from Poppodium 013, Tilburg, Netherlands"><span>Poppodium 013, Tilburg, Netherlands</span></a></span>
# </h1>
# ...
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-12 hiddenOnOutOfViewPort">
# <h3><em class="link"><span>Unlocked: Rico Nasty</span></em></h3>
# <div><span class="font-meek fontSmall"></span></div>
# </div>
# <div class="col-xs-12 hiddenOnOutOfViewPort">
# <ul class="commaList">
# <li class="noComma"><strong>Tagged</strong>: </li>
# <li><span><a href="../../../setlists/rico-nasty-3bcfb408.html" title="More Rico Nasty setlists"><span>Rico Nasty</span></a></span></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row" id="id3b">
# <div>
# <div class="contentAd" id="id5" style="display: none;">
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || Object.keys(consents).length !== 0) {
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# googletag.cmd.push(function() { googletag.display('id5'); });}
# });
# /*-->]]>*/
# </script>
# </div>
# </div>
# </div>
# <div data-google-query-id="CPKu2IOxz5IDFSTWewodWIk5yg" id="id6" style="display: none;">
# <div id="google_ads_iframe_/6025/setlist/setlist/syndication_0__container__" style="border: 0pt none;"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden-print footer">
# <div class="container">
# <!-- footer -->
# <div class="row">
# <div class="col-xs-12 col-md-6">
# <div class="footerBrowse">
# <strong>Browse artists</strong>
# <ul class="list-inline">
# <li>
# <a href="../../../artist/browse/a/1.html">
# <span>A</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/b/1.html">
# <span>B</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/c/1.html">
# <span>C</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/d/1.html">
# <span>D</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/e/1.html">
# <span>E</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/f/1.html">
# <span>F</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/g/1.html">
# <span>G</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/h/1.html">
# <span>H</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/i/1.html">
# <span>I</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/j/1.html">
# <span>J</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/k/1.html">
# <span>K</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/l/1.html">
# <span>L</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/m/1.html">
# <span>M</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/n/1.html">
# <span>N</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/o/1.html">
# <span>O</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/p/1.html">
# <span>P</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/q/1.html">
# <span>Q</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/r/1.html">
# <span>R</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/s/1.html">
# <span>S</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/t/1.html">
# <span>T</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/u/1.html">
# <span>U</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/v/1.html">
# <span>V</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/w/1.html">
# <span>W</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/x/1.html">
# <span>X</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/y/1.html">
# <span>Y</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/z/1.html">
# <span>Z</span>
# </a>
# </li><li>
# <a href="../../../artist/browse/0-9/1.html">
# <span>#</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xs-12 col-md-6">
# <div class="footerBrowse">
# <strong>Browse venues</strong>
# <ul class="list-inline">
# <li>
# <a href="../../../venues/browse/a/1.html">
# <span>A</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/b/1.html">
# <span>B</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/c/1.html">
# <span>C</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/d/1.html">
# <span>D</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/e/1.html">
# <span>E</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/f/1.html">
# <span>F</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/g/1.html">
# <span>G</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/h/1.html">
# <span>H</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/i/1.html">
# <span>I</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/j/1.html">
# <span>J</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/k/1.html">
# <span>K</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/l/1.html">
# <span>L</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/m/1.html">
# <span>M</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/n/1.html">
# <span>N</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/o/1.html">
# <span>O</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/p/1.html">
# <span>P</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/q/1.html">
# <span>Q</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/r/1.html">
# <span>R</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/s/1.html">
# <span>S</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/t/1.html">
# <span>T</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/u/1.html">
# <span>U</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/v/1.html">
# <span>V</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/w/1.html">
# <span>W</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/x/1.html">
# <span>X</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/y/1.html">
# <span>Y</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/z/1.html">
# <span>Z</span>
# </a>
# </li><li>
# <a href="../../../venues/browse/0-9/1.html">
# <span>#</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <hr class="divider"/>
# <div class="row">
# <div class="col-xs-12 col-sm-6 col-md-3">
# <strong>Recent Events</strong>
# <ul class="linkList list-unstyled">
# <li><span><a href="../../../search?query=date:2026-02-10" title='Search setlists by day: "Today"'><span>Today</span></a></span></li><li><span><a href="../../../search?query=date:2026-02-09" title='Search setlists by day: "Yesterday"'><span>Yesterday</span></a></span></li><li><span><a href="../../../search?query=date:2026-02-08" title='Search setlists by day: "Feb 8, 2026"'><span>Feb 8, 2026</span></a></span></li><li><span><a href="../../../search?query=date:2026-02-07" title='Search setlists by day: "Feb 7, 2026"'><span>Feb 7, 2026</span></a></span></li><li><span><a href="../../../search?query=date:2026-02-06" title='Search setlists by day: "Feb 6, 2026"'><span>Feb 6, 2026</span></a></span></li><li><span><a href="../../../search?query=date:2026-02-05" title='Search setlists by day: "Feb 5, 2026"'><span>Feb 5, 2026</span></a></span></li><li><span><a href="../../../search?query=date:2026-02-04" title='Search setlists by day: "Feb 4, 2026"'><span>Feb 4, 2026</span></a></span></li><li><span><a href="../../../search?query=date:2026-02-03" title='Search setlists by day: "Feb 3, 2026"'><span>Feb 3, 2026</span></a></span></li>
# </ul>
# <strong class="headlineMargin">Theme</strong>
# <ul class="list-inline themeList">
# <li class="active">
# <a class="footerThemeLink system" data-theme-active="system" href="javascript:;" rel="nofollow">
# <span>Auto</span>
# </a>
# <span class="system">
# <span>Auto</span>
# </span>
# </li>
# <li>
# <a class="footerThemeLink dark" data-theme-active="dark" href="javascript:;" rel="nofollow">
# <span>Dark</span>
# </a>
# <span class="dark">
# <span>Dark</span>
# </span>
# </li>
# <li>
# <a class="footerThemeLink light" data-theme-active="light" href="javascript:;" rel="nofollow">
# <span>Light</span>
# </a>
# <span class="light">
# <span>Light</span>
# </span>
# </li>
# </ul>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3">
# <strong>© setlist.fm</strong>
# <ul class="linkList list-unstyled" id="id2c">
# <li>
# <a href="../../../guidelines" title="Guidelines">
# <span>Guidelines</span>
# </a>
# </li>
# <li>
# <a href="../../../faq" title="Frequently Asked Questions"><span>FAQ</span></a>
# <span class="footerItemDivider">|</span>
# <a href="../../../help" title="Help"><span>Help</span></a>
# <span class="footerItemDivider">|</span>
# <a href="../../../about" title="What the heck is setlist.fm about?"><span>About</span></a>
# </li>
# <li>
# <a href="../../../contact" rel="nofollow" title="Don't be afraid to contact us!"><span>Contact us</span></a>
# </li>
# <li>
# <a href="../../../help/terms" title="Read the setlist.fm Terms of Service">
# <span>Terms of Service</span>
# </a>
# </li>
# <li>
# <a href="../../../help/ad-choices" title="About Ad Choices on setlist.fm"><span>Ad Choices</span></a>
# <span class="footerItemDivider">|</span>
# <a href="../../../help/privacy" title="Read the setlist.fm Privacy Policy"><span>Privacy Policy</span></a>
# </li>
# <li><a href="#" onclick='window.__tcfapi("displayConsentUi",2, function() {}); return false;' title="Edit your consent preferences">Privacy Settings</a></li></ul>
# </div>
# <div class="clearfix visible-sm-block"></div>
# <div class="col-xs-12 col-sm-6 col-md-3">
# <strong>Social</strong>
# <ul class="linkList list-unstyled">
# <li><a class="nested" href="https://www.facebook.com/setlist.fm"><i class="fa fa-facebook fa-fw"></i> <span>Like us</span> <i class="fa fa-external-link"></i></a></li>
# <li><a class="nested" href="https://twitter.com/setlistfm"><i class="fa fa-twitter fa-fw"></i> <span>Follow us</span> <i class="fa fa-external-link"></i></a></li>
# <li><a class="nested" href="https://www.instagram.com/setlist.fm"><i class="fa fa-instagram fa-fw"></i> <span>Follow us</span> <i class="fa fa-external-link"></i></a></li>
# <li><a href="https://api.setlist.fm/" title="Use our API for your applications!">API</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3">
# <strong>Links</strong>
# <ul class="linkList list-unstyled">
# <li><a class="nested" href="http://www.songtexte.com/" title="Lyrics by Songtexte.com"><span>Songtexte.com</span> <i class="fa fa-external-link"></i></a></li>
# <li><a class="nested" href="http://www.molindo.at/" title="Programming by Molindo.at"><span>Molindo.at</span> <i class="fa fa-external-link"></i></a></li>
# </ul>
# <strong class="headlineMargin">Friends &amp; Partners</strong>
# <ul class="linkList list-unstyled partners">
# <li>
# <a href="https://www.eventticketprotection.com/tm/" rel="nofollow noopener" target="_blank" title="Allianz Global Assistance">
# <span class="linkList-sprite linkList-sprite-allianz"></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden-print">
# <div class="comscore">
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || consents['5']) {
#
#  window._comscore = window._comscore || [];
# _comscore.push({ c1: "2", c2: "3005317", cs_ucfr: "1" });
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();} else {
#
#  window._comscore = window._comscore || [];
# _comscore.push({ c1: "2", c2: "3005317", cs_ucfr: "0" });
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();}
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# }
# });
# /*-->]]>*/
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=3005317&amp;cv=2.0&amp;cj=1">
# </img></noscript>
# </div>
# </div>
# <div class="hidden-print"></div>
# <div class="hidden-print">
# <div class="quantcast">
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || consents['5']) {
#
# window._qevents = window._qevents || [];
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
# _qevents.push({
# qacct:"p-98KjJHhiQX_yM"
# });} else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# }
# });
# /*-->]]>*/
# </script>
# <noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-98KjJHhiQX_yM.gif" width="1">
# </img></div>
# </noscript>
# </div>
# </div>
# <div class="hidden-print">
# </div>
# </div>
# <div class="adhesion closeableAd" data-google-query-id="CPSu2IOxz5IDFSTWewodWIk5yg" id="id9" style="display: none;">
# <script type="text/javascript">
# <!--/*--><![CDATA[/*><!--*/
# window.__tcfapi("addEventListener", 2, function(tcData, success) {
# if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded')){
# var consents = tcData.gdprApplies === true ? tcData.purpose.consents : null;
# if (!tcData.gdprApplies || Object.keys(consents).length !== 0) {
# } else {
# }
#     window.__tcfapi('removeEventListener', 2, (success) => {}, tcData.listenerId);
# googletag.cmd.push(function() { googletag.display('id9'); });}
# });
# /*-->]]>*/
# </script>
# <div id="google_ads_iframe_/6025/setlist/setlist/adhesion_0__container__" style="border: 0pt none; width: 320px; height: 50px;"></div></div>
# <script id="SetlistActivitiesPanel" type="text/javascript">
# window.SetlistWidgetSetlistActivityConfig = {"setlist":{"urn":"urn:setlist:setlist:3358a08d"},"showSuggestions":true,"canApproveSuggestions":false}
# </script>
# <iframe data-gtm-yt-inspected-8="true" name="__tcfapiLocator" style="display: none;"></iframe><iframe data-gtm-yt-inspected-8="true" name="__gppLocator" style="display: none;"></iframe><iframe data-gtm-yt-inspected-8="true" height="0" src="https://www.google.com/recaptcha/api2/aframe" style="display: none;" width="0"></iframe></body><iframe data-gtm-yt-inspected-8="true" id="goog_plcm_frame" src="https://cm.g.doubleclick.net/partnerpixels?gdpr=0&amp;us_privacy=1---&amp;gpp_sid=-1&amp;url=https%3A%2F%2Fwww.setlist.fm%2Fsetlist%2Fthe-plot-in-you%2F2025%2Fpoppodium-013-tilburg-netherlands-3358a08d.html" style="display: none;"></iframe></html>

# %%
test = soup.find("meta", property="qc:artist")
print(type(test["content"]))
# print(soup)
# driver.quit()

# Extract songs

# songs = [li.get_text(strip=True).removesuffix('Play Video') for li in soup.select("li.setlistParts.song")]
# print(songs)
# Out:
# <class 'str'>
